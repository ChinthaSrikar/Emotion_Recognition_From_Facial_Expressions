# %%
import os
import torch
import torchvision
# !pip install torchsummary
import torch.nn as nn
from torchvision import models
from torchsummary import summary
# Out:
# Collecting torchsummary
#   Downloading torchsummary-1.5.1-py3-none-any.whl.metadata (296 bytes)
# Downloading torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Installing collected packages: torchsummary
# Successfully installed torchsummary-1.5.1

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
# minibatch size
batch_size = 16

# %% [markdown]
# # PreProcessing

# %%
from torchvision import transforms
from PIL import Image

# Define resize operation
resize = transforms.Resize((98, 98))

# Define transformations for both training and testing
transformations = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),  # Convert to grayscale
    resize,
    transforms.RandomHorizontalFlip(),  # Data augmentation
    transforms.RandomRotation(10),  # Data augmentation
    transforms.RandomResizedCrop((98, 98), scale=(0.8, 1.2), interpolation=Image.BILINEAR),  # Random crop
    #transforms.RandomApply([transforms.RandomErasing()], p=0.5),  # Random erasing
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)),  # Normalizing for grayscale image
])

# Use the same transformations for both training and testing datasets
trainTransforms = transformations
testTransforms = transformations

# %%
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torch.utils.data import random_split


# Load the dataset from the image folder
dataset = datasets.ImageFolder(root='/kaggle/input/facial-emotion-detection/Facial emotion/train', transform=trainTransforms)

# Calculate the sizes for train and validation sets
train_size = int(0.7 * len(dataset))
val_size = len(dataset) - train_size

# Split the dataset
train_data, validation_data = random_split(dataset, [train_size, val_size])
# Setup the batch size hyperparameter
BATCH_SIZE = batch_size
test_data = ImageFolder('//kaggle/input/facial-emotion-detection/Facial emotion/test', transform=testTransforms)

# Turn datasets into iterables (batches)
train_dataloader = DataLoader(train_data,
                              batch_size=BATCH_SIZE,
                              shuffle=True)

validation_dataloader = DataLoader(validation_data,
                              batch_size=BATCH_SIZE,
                              shuffle=True)

test_dataloader = DataLoader(test_data,
                             batch_size=BATCH_SIZE,
                             shuffle=False)


# Let's check out what we've created
print(f"Dataloaders: {train_dataloader, test_dataloader}")
print(f"Length of train dataloader: {len(train_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of Validation dataloader: {len(validation_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of test dataloader: {len(test_dataloader)} batches of {BATCH_SIZE}")
# Out:
# Dataloaders: (<torch.utils.data.dataloader.DataLoader object at 0x79e86c220d30>, <torch.utils.data.dataloader.DataLoader object at 0x79e86c222620>)
# Length of train dataloader: 1256 batches of 16
# Length of Validation dataloader: 539 batches of 16
# Length of test dataloader: 449 batches of 16

# %%
nb_train_samples = 1256 * 16
nb_validation_samples = 539 * 16
nb_test_samples = 449 * 16

# %%
import torch
import torch.nn as nn

# Defining the neural network
class FIVE_CNN(nn.Module):
    def __init__(self):
        super(FIVE_CNN, self).__init__()
        
        # Convolutional blocks: Conv layer => BatchNorm => ReLU
        self.conv_block1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        
        self.conv_block2 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        
        self.conv_block3 = nn.Sequential(
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        
        self.conv_block4 = nn.Sequential(
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        
        self.conv_block5 = nn.Sequential(
            nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=3, padding=1),
            nn.BatchNorm2d(1024),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        
        
        # Adaptive average pooling
        self.adaptive_avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        
        # Fully connected layers
        self.fc_layers = nn.Sequential(
            nn.Linear(1024, 4096),  # Adjust the linear layer size based on your conv output
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(4096, 7),
        ) 
        
  

    def forward(self, x):
        x = self.conv_block1(x)
        x = self.conv_block2(x)
        x = self.conv_block3(x)
        x = self.conv_block4(x)
        x = self.conv_block5(x)
        x = self.adaptive_avg_pool(x)
        x = x.view(x.size(0), -1)  # Flatten the tensor
        x = self.fc_layers(x)
        return x

# Instantiating the model
model = FIVE_CNN()

# %% [markdown]
# # **KLD + ADAM ON NEW MODEL**

# %%
import torch
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau

# Define Kullback-Leibler Divergence (KLD) Loss Function
import torch.nn.functional as F

def kld_loss(outputs, labels):
    log_probs = F.log_softmax(outputs, dim=1)
    target_probs = F.one_hot(labels, num_classes=outputs.size(1))  # Convert labels to one-hot vectors
    target_probs = target_probs.float()
    return F.kl_div(log_probs, target_probs, reduction='batchmean')
 

# Adam Optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)


# Number of epochs
num_epochs = 50



# Move model to GPU if available
model = model.to(device)

# Training Loop
for epoch in range(num_epochs):
    # Training phase
    model.train()
    running_loss = 0.0
    running_corrects = 0

    for inputs, labels in train_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = kld_loss(outputs, labels)  # Use KLD loss here
        _, preds = torch.max(outputs, 1)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(train_dataloader.dataset)
    epoch_acc = running_corrects.double() / len(train_dataloader.dataset)
    print(f'Epoch {epoch}/{num_epochs - 1} - Training loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}')

    # Validation phase
    model.eval()
    val_running_loss = 0.0
    val_running_corrects = 0
    
    with torch.no_grad():
        for inputs, labels in validation_dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = kld_loss(outputs, labels)  # Use KLD loss here
            _, preds = torch.max(outputs, 1)
            val_running_loss += loss.item() * inputs.size(0)
            val_running_corrects += torch.sum(preds == labels.data)

    val_epoch_loss = val_running_loss / len(validation_dataloader.dataset)
    val_epoch_acc = val_running_corrects.double() / len(validation_dataloader.dataset)
    print(f'Epoch {epoch}/{num_epochs - 1} - Validation loss: {val_epoch_loss:.4f}, Accuracy: {val_epoch_acc:.4f}')

    

# Save the model after training
#torch.save(model.state_dict(), 'vggnet_kld_adam.pth')
# Out:
# Epoch 0/49 - Training loss: 1.8409, Accuracy: 0.2372
# Epoch 0/49 - Validation loss: 1.8113, Accuracy: 0.2547
# Epoch 1/49 - Training loss: 1.8166, Accuracy: 0.2488
# Epoch 1/49 - Validation loss: 1.8082, Accuracy: 0.2571
# Epoch 2/49 - Training loss: 1.8160, Accuracy: 0.2483
# Epoch 2/49 - Validation loss: 1.8087, Accuracy: 0.2571
# Epoch 3/49 - Training loss: 1.8146, Accuracy: 0.2486
# Epoch 3/49 - Validation loss: 1.8103, Accuracy: 0.2571
# Epoch 4/49 - Training loss: 1.8177, Accuracy: 0.2428
# Epoch 4/49 - Validation loss: 1.7824, Accuracy: 0.2710
# Epoch 5/49 - Training loss: 1.7504, Accuracy: 0.2756
# Epoch 5/49 - Validation loss: 1.7084, Accuracy: 0.3052
# Epoch 6/49 - Training loss: 1.6362, Accuracy: 0.3342
# Epoch 6/49 - Validation loss: 1.5047, Accuracy: 0.3977
# Epoch 7/49 - Training loss: 1.4807, Accuracy: 0.4103
# Epoch 7/49 - Validation loss: 1.3773, Accuracy: 0.4537
# Epoch 8/49 - Training loss: 1.3960, Accuracy: 0.4568
# Epoch 8/49 - Validation loss: 1.3461, Accuracy: 0.4809
# Epoch 9/49 - Training loss: 1.3223, Accuracy: 0.4907
# Epoch 9/49 - Validation loss: 1.2427, Accuracy: 0.5189
# Epoch 10/49 - Training loss: 1.2610, Accuracy: 0.5182
# Epoch 10/49 - Validation loss: 1.2212, Accuracy: 0.5316
# Epoch 11/49 - Training loss: 1.2231, Accuracy: 0.5350
# Epoch 11/49 - Validation loss: 1.1668, Accuracy: 0.5475
# Epoch 12/49 - Training loss: 1.1913, Accuracy: 0.5460
# Epoch 12/49 - Validation loss: 1.1662, Accuracy: 0.5551
# Epoch 13/49 - Training loss: 1.1606, Accuracy: 0.5585
# Epoch 13/49 - Validation loss: 1.1403, Accuracy: 0.5604
# Epoch 14/49 - Training loss: 1.1347, Accuracy: 0.5710
# Epoch 14/49 - Validation loss: 1.1392, Accuracy: 0.5677
# Epoch 15/49 - Training loss: 1.1107, Accuracy: 0.5817
# Epoch 15/49 - Validation loss: 1.1302, Accuracy: 0.5701
# Epoch 16/49 - Training loss: 1.0869, Accuracy: 0.5918
# Epoch 16/49 - Validation loss: 1.1019, Accuracy: 0.5805
# Epoch 17/49 - Training loss: 1.0726, Accuracy: 0.6008
# Epoch 17/49 - Validation loss: 1.0903, Accuracy: 0.5838
# Epoch 18/49 - Training loss: 1.0499, Accuracy: 0.6066
# Epoch 18/49 - Validation loss: 1.0685, Accuracy: 0.5932
# Epoch 19/49 - Training loss: 1.0373, Accuracy: 0.6124
# Epoch 19/49 - Validation loss: 1.0759, Accuracy: 0.5978
# Epoch 20/49 - Training loss: 1.0193, Accuracy: 0.6181
# Epoch 20/49 - Validation loss: 1.0416, Accuracy: 0.5999
# Epoch 21/49 - Training loss: 1.0080, Accuracy: 0.6227
# Epoch 21/49 - Validation loss: 1.0514, Accuracy: 0.5977
# Epoch 22/49 - Training loss: 0.9898, Accuracy: 0.6300
# Epoch 22/49 - Validation loss: 1.0375, Accuracy: 0.6094
# Epoch 23/49 - Training loss: 0.9766, Accuracy: 0.6380
# Epoch 23/49 - Validation loss: 1.0239, Accuracy: 0.6124
# Epoch 24/49 - Training loss: 0.9557, Accuracy: 0.6429
# Epoch 24/49 - Validation loss: 1.0451, Accuracy: 0.6064
# Epoch 25/49 - Training loss: 0.9446, Accuracy: 0.6490
# Epoch 25/49 - Validation loss: 1.0591, Accuracy: 0.6098
# Epoch 26/49 - Training loss: 0.9517, Accuracy: 0.6479
# Epoch 26/49 - Validation loss: 1.0388, Accuracy: 0.6025
# Epoch 27/49 - Training loss: 0.9242, Accuracy: 0.6552
# Epoch 27/49 - Validation loss: 1.0459, Accuracy: 0.6087
# Epoch 28/49 - Training loss: 0.9113, Accuracy: 0.6606
# Epoch 28/49 - Validation loss: 1.0088, Accuracy: 0.6266
# Epoch 29/49 - Training loss: 0.8991, Accuracy: 0.6676
# Epoch 29/49 - Validation loss: 1.0096, Accuracy: 0.6304
# Epoch 30/49 - Training loss: 0.8863, Accuracy: 0.6688
# Epoch 30/49 - Validation loss: 1.0163, Accuracy: 0.6185
# Epoch 31/49 - Training loss: 0.8719, Accuracy: 0.6793
# Epoch 31/49 - Validation loss: 1.0316, Accuracy: 0.6229
# Epoch 32/49 - Training loss: 0.8613, Accuracy: 0.6809
# Epoch 32/49 - Validation loss: 1.0276, Accuracy: 0.6308
# Epoch 33/49 - Training loss: 0.8550, Accuracy: 0.6846
# Epoch 33/49 - Validation loss: 1.0332, Accuracy: 0.6266
# Epoch 34/49 - Training loss: 0.8455, Accuracy: 0.6905
# Epoch 34/49 - Validation loss: 1.0491, Accuracy: 0.6205
# Epoch 35/49 - Training loss: 0.8332, Accuracy: 0.6910
# Epoch 35/49 - Validation loss: 1.0279, Accuracy: 0.6188
# Epoch 36/49 - Training loss: 0.8214, Accuracy: 0.6957
# Epoch 36/49 - Validation loss: 1.0299, Accuracy: 0.6248
# Epoch 37/49 - Training loss: 0.8115, Accuracy: 0.6994
# Epoch 37/49 - Validation loss: 1.0132, Accuracy: 0.6344
# Epoch 38/49 - Training loss: 0.8026, Accuracy: 0.7063
# Epoch 38/49 - Validation loss: 1.0186, Accuracy: 0.6287
# Epoch 39/49 - Training loss: 0.7979, Accuracy: 0.7070
# Epoch 39/49 - Validation loss: 1.0235, Accuracy: 0.6292
# Epoch 40/49 - Training loss: 0.7864, Accuracy: 0.7125
# Epoch 40/49 - Validation loss: 1.0311, Accuracy: 0.6264
# Epoch 41/49 - Training loss: 0.7716, Accuracy: 0.7163
# Epoch 41/49 - Validation loss: 1.0130, Accuracy: 0.6313
# Epoch 42/49 - Training loss: 0.7653, Accuracy: 0.7201
# Epoch 42/49 - Validation loss: 1.0492, Accuracy: 0.6280
# Epoch 43/49 - Training loss: 0.7592, Accuracy: 0.7249
# Epoch 43/49 - Validation loss: 1.0209, Accuracy: 0.6321
# Epoch 44/49 - Training loss: 0.7558, Accuracy: 0.7252
# Epoch 44/49 - Validation loss: 1.0541, Accuracy: 0.6332
# Epoch 45/49 - Training loss: 0.7368, Accuracy: 0.7323
# Epoch 45/49 - Validation loss: 1.0412, Accuracy: 0.6356
# Epoch 46/49 - Training loss: 0.7378, Accuracy: 0.7314
# Epoch 46/49 - Validation loss: 1.0393, Accuracy: 0.6259
# Epoch 47/49 - Training loss: 0.7257, Accuracy: 0.7336
# Epoch 47/49 - Validation loss: 1.0969, Accuracy: 0.6285
# Epoch 48/49 - Training loss: 0.7128, Accuracy: 0.7396
# Epoch 48/49 - Validation loss: 1.0444, Accuracy: 0.6351
# Epoch 49/49 - Training loss: 0.7049, Accuracy: 0.7424
# Epoch 49/49 - Validation loss: 1.0723, Accuracy: 0.6335

# %%
model.eval()  # Set the model to evaluation mode
test_loss = 0.0
test_corrects = 0

# You should define nb_test_samples before this block
# It should be the total number of samples in the test set
nb_test_samples = len(test_dataloader.dataset)

with torch.no_grad():
    for inputs, labels in test_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        loss = kld_loss(outputs, labels)
        test_loss += loss.item() * inputs.size(0)

        _, preds = torch.max(outputs, 1)
        test_corrects += torch.sum(preds == labels.data).item()

# Calculate the average loss and accuracy
test_epoch_loss = test_loss / nb_test_samples
test_epoch_accuracy = test_corrects / nb_test_samples
test_accuracy_percentage = test_epoch_accuracy * 100

print(f'Test loss: {test_epoch_loss:.4f}')
print(f'Test Accuracy: {test_accuracy_percentage:.2f}%')
# Out:
# Test loss: 1.0597
# Test Accuracy: 63.51%

# %% [markdown]
# # FOCAL LOSS + SGD + SCHEDULER - old model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class FocalLoss(nn.Module):
    def __init__(self, gamma=2, alpha=None):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha

    def forward(self, input, target):
        ce_loss = F.cross_entropy(input, target, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1 - pt) ** self.gamma * ce_loss
        if self.alpha is not None:
            focal_loss = self.alpha * focal_loss
        return focal_loss.mean()

# Usage example:
# Instantiate Focal Loss
criterion = FocalLoss(gamma=2, alpha=None)

# Then, in your training loop, use this `criterion` as your loss function:
# loss = criterion(outputs, labels)

# %%
import torch
import torch.optim as optim
from torch.autograd import Variable
from torch.optim.lr_scheduler import ReduceLROnPlateau

# Criterion and Optimizer
#criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9, nesterov=True)
model=model.to(device)
# Scheduler
scheduler = ReduceLROnPlateau(optimizer, 'max', factor=0.75, patience=5, verbose=True)

num_epochs = 25
print(torch.cuda.is_available())

for epoch in range(num_epochs):
    # Training phase
    model.train()
    running_loss = 0.0
    running_corrects = 0

    for inputs, labels in train_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        _, preds = torch.max(outputs, 1)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(train_dataloader.dataset)
    epoch_acc = running_corrects.double() / len(train_dataloader.dataset)
    print(f'Epoch {epoch}/{num_epochs - 1} - Training loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}')

    # Validation phase
    model.eval()
    val_running_loss = 0.0
    val_running_corrects = 0
    with torch.no_grad():
        for inputs, labels in validation_dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            _, preds = torch.max(outputs, 1)
            val_running_loss += loss.item() * inputs.size(0)
            val_running_corrects += torch.sum(preds == labels.data)

    val_epoch_loss = val_running_loss / len(validation_dataloader.dataset)
    val_epoch_acc = val_running_corrects.double() / len(validation_dataloader.dataset)
    print(f'Epoch {epoch}/{num_epochs - 1} - Validation loss: {val_epoch_loss:.4f}, Accuracy: {val_epoch_acc:.4f}')

    # Adjust learning rate based on validation accuracy
    scheduler.step(val_epoch_acc)

# Save the model after training
torch.save(model.state_dict(), 'vggnet_fer.pth')
# Out:
# True
# Epoch 0/24 - Training loss: 1.2278, Accuracy: 0.3029
# Epoch 0/24 - Validation loss: 1.0638, Accuracy: 0.3831
# Epoch 1/24 - Training loss: 1.0320, Accuracy: 0.3980
# Epoch 1/24 - Validation loss: 0.9593, Accuracy: 0.4306
# Epoch 2/24 - Training loss: 0.9550, Accuracy: 0.4368
# Epoch 2/24 - Validation loss: 0.9086, Accuracy: 0.4602
# Epoch 3/24 - Training loss: 0.8980, Accuracy: 0.4600
# Epoch 3/24 - Validation loss: 0.8588, Accuracy: 0.4806
# Epoch 4/24 - Training loss: 0.8623, Accuracy: 0.4800
# Epoch 4/24 - Validation loss: 0.8442, Accuracy: 0.4737
# Epoch 5/24 - Training loss: 0.8437, Accuracy: 0.4908
# Epoch 5/24 - Validation loss: 0.8326, Accuracy: 0.5091
# Epoch 6/24 - Training loss: 0.8149, Accuracy: 0.5004
# Epoch 6/24 - Validation loss: 0.8090, Accuracy: 0.5093
# Epoch 7/24 - Training loss: 0.7910, Accuracy: 0.5151
# Epoch 7/24 - Validation loss: 0.8501, Accuracy: 0.4720
# Epoch 8/24 - Training loss: 0.7799, Accuracy: 0.5200
# Epoch 8/24 - Validation loss: 0.8379, Accuracy: 0.4860
# Epoch 9/24 - Training loss: 0.7538, Accuracy: 0.5295
# Epoch 9/24 - Validation loss: 0.8020, Accuracy: 0.4871
# Epoch 10/24 - Training loss: 0.7422, Accuracy: 0.5341
# Epoch 10/24 - Validation loss: 0.7565, Accuracy: 0.5383
# Epoch 11/24 - Training loss: 0.7139, Accuracy: 0.5463
# Epoch 11/24 - Validation loss: 0.7532, Accuracy: 0.5283
# Epoch 12/24 - Training loss: 0.7096, Accuracy: 0.5496
# Epoch 12/24 - Validation loss: 0.7556, Accuracy: 0.5077
# Epoch 13/24 - Training loss: 0.6990, Accuracy: 0.5571
# Epoch 13/24 - Validation loss: 0.7506, Accuracy: 0.5503
# Epoch 14/24 - Training loss: 0.6763, Accuracy: 0.5624
# Epoch 14/24 - Validation loss: 0.7562, Accuracy: 0.5446
# Epoch 15/24 - Training loss: 0.6627, Accuracy: 0.5746
# Epoch 15/24 - Validation loss: 0.7607, Accuracy: 0.5304
# Epoch 16/24 - Training loss: 0.6459, Accuracy: 0.5808
# Epoch 16/24 - Validation loss: 0.7207, Accuracy: 0.5596
# Epoch 17/24 - Training loss: 0.6417, Accuracy: 0.5817
# Epoch 17/24 - Validation loss: 0.7509, Accuracy: 0.5351
# Epoch 18/24 - Training loss: 0.6423, Accuracy: 0.5820
# Epoch 18/24 - Validation loss: 0.7651, Accuracy: 0.5362
# Epoch 19/24 - Training loss: 0.6203, Accuracy: 0.5967
# Epoch 19/24 - Validation loss: 0.7500, Accuracy: 0.5568
# Epoch 20/24 - Training loss: 0.6103, Accuracy: 0.5930
# Epoch 20/24 - Validation loss: 0.7248, Accuracy: 0.5626
# Epoch 21/24 - Training loss: 0.6102, Accuracy: 0.5996
# Epoch 21/24 - Validation loss: 0.7172, Accuracy: 0.5633
# Epoch 22/24 - Training loss: 0.5965, Accuracy: 0.6050
# Epoch 22/24 - Validation loss: 0.7398, Accuracy: 0.5563
# Epoch 23/24 - Training loss: 0.5870, Accuracy: 0.6059
# Epoch 23/24 - Validation loss: 0.7289, Accuracy: 0.5412
# Epoch 24/24 - Training loss: 0.5848, Accuracy: 0.6071
# Epoch 24/24 - Validation loss: 0.7015, Accuracy: 0.5631

# %%
model.eval()  # Set the model to evaluation mode
test_loss = 0.0
test_corrects = 0

# You should define nb_test_samples before this block
# It should be the total number of samples in the test set
nb_test_samples = len(test_dataloader.dataset)

with torch.no_grad():
    for inputs, labels in test_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        test_loss += loss.item() * inputs.size(0)

        _, preds = torch.max(outputs, 1)
        test_corrects += torch.sum(preds == labels.data).item()

# Calculate the average loss and accuracy
test_epoch_loss = test_loss / nb_test_samples
test_epoch_accuracy = test_corrects / nb_test_samples
test_accuracy_percentage = test_epoch_accuracy * 100

print(f'Test loss: {test_epoch_loss:.4f}')
print(f'Test Accuracy: {test_accuracy_percentage:.2f}%')
# Out:
# Test loss: 0.6841
# Test Accuracy: 56.91%

# %% [markdown]
# #
